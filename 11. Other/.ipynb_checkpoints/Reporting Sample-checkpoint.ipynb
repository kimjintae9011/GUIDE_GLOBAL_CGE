# %%
import gdxpds
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# GDX 파일 경로를 지정합니다.
gdx_file_path = 'BAU_Results_GTAP11c_new.gdx'

# GDX 파일을 데이터프레임 딕셔너리로 불러옵니다.
gdx_data = gdxpds.to_dataframes(gdx_file_path)

# 불러온 데이터 확인
print("GDX 파일에 포함된 요소들:", list(gdx_data.keys()))
# Out:
# GDX 파일에 포함된 요소들: ['valA_VA', 'valC', 'valCAB', 'valCABX', 'valCG', 'valCI', 'valCE', 'valCMIN', 'valCTH', 'valCTH_REAL', 'valDD', 'valDEP', 'valDI', 'valDE', 'valDIT', 'valDS', 'valDS_I', 'vale', 'valEX', 'valEXT', 'valG', 'ValG_REAL', 'valGDP_BP', 'valGDP_BP_REAL', 'valGDP_BP_W', 'valGDP_BP_W_REAL', 'valGDP_FD', 'valGDP_IB', 'valGDP_MP', 'valGDP_MP_REAL', 'valIM', 'valIMT', 'valIND', 'valINV', 'valIR', 'valIT', 'valIT_REAL', 'valKD', 'valKDC', 'valKS', 'valLD', 'valLDC', 'valLS', 'valLST', 'valMRGN', 'valP', 'valPC', 'valPCI', 'valPCE', 'valPD', 'valPE', 'valPET', 'valphi', 'valPIXCON', 'valPIXCON2', 'valPIXGDP', 'valPIXGDP_W', 'valPIXGVT', 'valPIXINV', 'valPK', 'valPL', 'valPM', 'valPMT', 'valPP', 'valPT', 'valPVA', 'valPKLE', 'valPWM', 'valPWMG', 'valPWX', 'valQ', 'valR', 'valRC', 'valRTI', 'valSG', 'valSH', 'valsh0', 'valsh1', 'valSROW', 'valTDH', 'valTIC', 'valTICT', 'valTIK', 'valTIKT', 'valTIM', 'valTIMT', 'valTIP', 'valTIPT', 'valTIW', 'valTIWT', 'valTIX', 'valTIXT', 'valTPRCTS', 'valTPRODN', 'valttdh0', 'valttdh1', 'valttic', 'valttik', 'valttim', 'valttip', 'valttiw', 'valttix', 'valU', 'valVA', 'valKLE', 'valW', 'valWC', 'valWTI', 'valXS', 'valYDH', 'valYG', 'valYH', 'valYHK', 'valYHL', 'valYROW', 'valEE', 'valNE', 'valEH', 'valTFC_product', 'valTFC', 'valNEA_TFC', 'valKOR_TFC', 'valCHN_TFC', 'valJPN_TFC', 'valTES_coal', 'valTES_gas', 'valTES_oil', 'valTES', 'valCO2I', 'valCO2NE', 'valCO2H', 'valCO2I2', 'valCO2NE2', 'valCO2I3', 'valTCO2I', 'valTCO2NE', 'valTCO2H', 'valTCO2', 'valEndo_CO2', 'valEndo_TotalCO2', 'valCH4I', 'valCH4H', 'valCH4I2', 'valCH4I3', 'valTCH4I', 'valTCH4H', 'valTCH4', 'valN2OI', 'valN2OH', 'valN2OI2', 'valN2OI3', 'valTN2OI', 'valTN2OH', 'valTN2O', 'valGlobal_CO2', 'valGlobal_CH4', 'valGlobal_N2O', 'valPOWER', 'valElecGen', 'valCTAX', 'valAEEI', 'valswitch', 'valpenetration_rate', 'valC_Conventional', 'valXDBS', 'valXDBS2', 'valLBS', 'valKBS', 'valCLBS', 'valCKBS', 'valMARKUP', 'valMARKUP_RATIO', 'valTCO2_Marine', 'valTCO2_Aviation', 'valPERMIT_TOTAL', 'valCO2FACTOR']

# %%
# 한글 폰트 설정 (Mac의 경우 'AppleGothic', Windows의 경우 'Malgun Gothic' 등)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 깨짐 방지

# %% [markdown]
# ## 가계 소비량 분석

# %%
valC_df = gdx_data['valC']

# %%
korea_data
# Out:
#                  I       Z  TIME SCEN      Value
# 0      01_AGRICULT  01_KOR  2019  BAU   1.361031
# 1      01_AGRICULT  01_KOR  2020  BAU   1.377792
# 2      01_AGRICULT  01_KOR  2021  BAU   1.435662
# 3      01_AGRICULT  01_KOR  2022  BAU   1.473837
# 4      01_AGRICULT  01_KOR  2023  BAU   1.503227
# ...            ...     ...   ...  ...        ...
# 11995       23_SER  01_KOR  2046  BAU  72.023941
# 11996       23_SER  01_KOR  2047  BAU  72.325183
# 11997       23_SER  01_KOR  2048  BAU  72.620505
# 11998       23_SER  01_KOR  2049  BAU  72.914594
# 11999       23_SER  01_KOR  2050  BAU  73.203967
#
# [736 rows x 5 columns]

# %%
korea_data = valC_df[valC_df['Z'].str.contains('01_KOR')].copy()

# %%
korea_data['TIME'] = korea_data['TIME'].astype(int)
korea_data = korea_data.sort_values(by='TIME')

# %%
pivoted_data = korea_data.pivot_table(index='TIME', columns='I', values='Value', aggfunc='sum')

# 피벗 후 결측치(NaN)가 있다면 0으로 채워줍니다. (그래프 깨짐 방지)
pivoted_data = pivoted_data.fillna(0)

# %%
# 4. 시각화
# 한글 폰트 설정 (Mac: 'AppleGothic', Windows: 'Malgun Gothic')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 깨짐 방지

# stacked=True 옵션이 누적 그래프를 만드는 핵심입니다.
pivoted_data.plot(kind='area', stacked=True, figsize=(12, 8), alpha=0.7)

plt.title('한국(KOR)의 상품별 연도별 누적 값', fontsize=16)
plt.xlabel('연도', fontsize=12)
plt.ylabel('10billion$', fontsize=12)
plt.legend(title='상품(I)', bbox_to_anchor=(1.02, 1), loc='upper left') # 범례를 그래프 바깥에 표시
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout() # 레이아웃 최적화

plt.show()

# 피벗된 데이터 확인
print("피벗된 데이터 (그래프 생성용):")
print(pivoted_data)
# Out:
# 피벗된 데이터 (그래프 생성용):
# I     01_AGRICULT   02_COAL    03_OIL    04_GAS  05_MINING  06_FOODPRO  \
# TIME
# 2019     1.361031  0.008147  0.000009  0.441530   0.002193    4.812295
# 2020     1.377792  0.008408  0.000010  0.450614   0.002256    4.832671
# 2021     1.435662  0.008742  0.000010  0.471252   0.002322    5.041124
# 2022     1.473837  0.009197  0.000011  0.496349   0.002462    5.165454
# 2023     1.503227  0.009671  0.000011  0.521896   0.002562    5.269876
# 2024     1.529969  0.009897  0.000011  0.543444   0.002647    5.368201
# 2025     1.555805  0.010263  0.000012  0.551640   0.002719    5.464478
# 2026     1.589745  0.010717  0.000012  0.579812   0.002839    5.586833
# 2027     1.623747  0.011215  0.000013  0.607187   0.002951    5.708728
# 2028     1.657378  0.011642  0.000013  0.631258   0.003058    5.829196
# 2029     1.690690  0.012091  0.000014  0.656098   0.003162    5.948442
# 2030     1.723780  0.012473  0.000014  0.677250   0.003262    6.066797
# 2031     1.750790  0.012936  0.000015  0.702146   0.003377    6.163293
# 2032     1.776624  0.013277  0.000015  0.721296   0.003477    6.257260
# 2033     1.801883  0.013711  0.000016  0.743158   0.003575    6.349665
# 2034     1.826883  0.014028  0.000016  0.761962   0.003668    6.441004
# 2035     1.851625  0.014452  0.000017  0.784121   0.003762    6.531277
# 2036     1.871374  0.014802  0.000017  0.804104   0.003866    6.603012
# 2037     1.890159  0.015209  0.000018  0.826517   0.003960    6.672288
# 2038     1.908531  0.015544  0.000018  0.845177   0.004047    6.740620
# 2039     1.926624  0.015921  0.000019  0.866395   0.004133    6.807856
# 2040     1.944566  0.016241  0.000019  0.884077   0.004214    6.874692
# 2041     1.959187  0.016610  0.000020  0.904850   0.004305    6.929131
# 2042     1.973266  0.016931  0.000020  0.922288   0.004388    6.982485
# 2043     1.986975  0.017282  0.000021  0.942090   0.004469    7.034623
# 2044     2.000457  0.017592  0.000021  0.959030   0.004545    7.086221
# 2045     2.013752  0.017925  0.000021  0.977901   0.004621    7.136970
# 2046     2.024322  0.018239  0.000022  0.995035   0.004702    7.177952
# 2047     2.034428  0.018567  0.000022  1.013426   0.004779    7.217649
# 2048     2.044249  0.018871  0.000023  1.030116   0.004851    7.256635
# 2049     2.053862  0.019180  0.000023  1.047472   0.004922    7.294838
# 2050     2.063332  0.019474  0.000023  1.063707   0.004990    7.332548
#
# I     07_TEXTILES  08_WOODPRO  09_PAPERPRO  10_PETROLCOAL  ...  14_NONFERR  \
# TIME                                                       ...
# 2019     2.878045    0.015661     0.103017       1.509743  ...    0.000829
# 2020     2.864463    0.015745     0.102756       1.536478  ...    0.000836
# 2021     2.989263    0.016427     0.107406       1.607599  ...    0.000871
# 2022     3.057780    0.016968     0.110277       1.685920  ...    0.000913
# 2023     3.120582    0.017446     0.112741       1.755981  ...    0.000948
# 2024     3.182250    0.017902     0.115250       1.825033  ...    0.000981
# 2025     3.244007    0.018355     0.117939       1.884166  ...    0.001013
# 2026     3.320285    0.018863     0.120666       1.966422  ...    0.001052
# 2027     3.396247    0.019366     0.123385       2.047537  ...    0.001090
# 2028     3.471494    0.019861     0.126111       2.128132  ...    0.001127
# 2029     3.545999    0.020348     0.128792       2.206781  ...    0.001163
# 2030     3.620158    0.020831     0.131510       2.284898  ...    0.001199
# 2031     3.681420    0.021269     0.133755       2.363506  ...    0.001237
# 2032     3.742114    0.021698     0.136054       2.441199  ...    0.001272
# 2033     3.802042    0.022118     0.138266       2.514745  ...    0.001306
# 2034     3.861563    0.022532     0.140487       2.590075  ...    0.001340
# 2035     3.920322    0.022938     0.142601       2.662040  ...    0.001373
# 2036     3.966724    0.023288     0.144378       2.736762  ...    0.001407
# 2037     4.012230    0.023626     0.146033       2.808176  ...    0.001439
# 2038     4.057693    0.023960     0.147737       2.878795  ...    0.001470
# 2039     4.102535    0.024286     0.149350       2.947436  ...    0.001500
# 2040     4.147407    0.024611     0.151020       3.015418  ...    0.001530
# 2041     4.184274    0.024899     0.152389       3.083304  ...    0.001561
# 2042     4.220994    0.025182     0.153797       3.150253  ...    0.001590
# 2043     4.257098    0.025458     0.155116       3.215669  ...    0.001620
# 2044     4.293154    0.025732     0.156475       3.280176  ...    0.001648
# 2045     4.328677    0.026000     0.157761       3.343427  ...    0.001677
# 2046     4.358044    0.026242     0.158906       3.407858  ...    0.001706
# 2047     4.386842    0.026476     0.159982       3.470961  ...    0.001734
# 2048     4.415472    0.026708     0.161070       3.532908  ...    0.001761
# 2049     4.443692    0.026934     0.162113       3.593553  ...    0.001789
# 2050     4.471718    0.027157     0.163158       3.653153  ...    0.001815
#
# I     15_MACHINE  16_TRANSEQ  17_OTHERIND   18_ELEC  19_CONSTRUC   20_LTRP  \
# TIME
# 2019    3.124120    2.722409     0.587683  0.986553     0.011557  1.573668
# 2020    3.122328    2.704665     0.581891  1.013883     0.011434  1.565147
# 2021    3.276464    2.828609     0.605743  1.066044     0.011881  1.628167
# 2022    3.387791    2.893702     0.617046  1.113709     0.012048  1.663016
# 2023    3.490353    2.954883     0.627611  1.141473     0.012219  1.695571
# 2024    3.588249    3.014502     0.637292  1.195613     0.012383  1.727244
# 2025    3.682690    3.074439     0.646172  1.294913     0.012542  1.756352
# 2026    3.792360    3.146530     0.659452  1.320752     0.012776  1.798686
# 2027    3.901983    3.217497     0.672584  1.347337     0.013006  1.840534
# 2028    4.010109    3.287677     0.685320  1.382280     0.013232  1.881806
# 2029    4.117524    3.357066     0.697966  1.414062     0.013459  1.922587
# 2030    4.223706    3.426115     0.710241  1.457933     0.013681  1.962875
# 2031    4.319314    3.484296     0.720050  1.485670     0.013849  1.997094
# 2032    4.412047    3.542180     0.729284  1.534253     0.014014  2.030601
# 2033    4.504225    3.599342     0.738665  1.572559     0.014181  2.063460
# 2034    4.595254    3.656096     0.747742  1.619092     0.014343  2.096244
# 2035    4.686268    3.712150     0.757063  1.649391     0.014508  2.128600
# 2036    4.764528    3.758621     0.763708  1.684132     0.014622  2.155933
# 2037    4.841577    3.804076     0.770506  1.703970     0.014739  2.182733
# 2038    4.917225    3.849426     0.776999  1.737632     0.014852  2.209022
# 2039    4.992514    3.894088     0.783667  1.757750     0.014967  2.235029
# 2040    5.066788    3.938835     0.790053  1.791833     0.015078  2.260597
# 2041    5.134613    3.977318     0.795132  1.810512     0.015159  2.282685
# 2042    5.201044    4.015812     0.799939  1.841821     0.015238  2.304310
# 2043    5.267059    4.053636     0.804898  1.860418     0.015318  2.325714
# 2044    5.332183    4.091473     0.809638  1.889922     0.015396  2.346687
# 2045    5.396997    4.128759     0.814498  1.908827     0.015474  2.367470
# 2046    5.455672    4.161351     0.817989  1.934569     0.015526  2.385400
# 2047    5.513606    4.193400     0.821547  1.952377     0.015579  2.403083
# 2048    5.570764    4.225298     0.824975  1.975876     0.015630  2.420359
# 2049    5.627444    4.256768     0.828434  1.994266     0.015681  2.437350
# 2050    5.683549    4.288077     0.831805  2.015967     0.015731  2.454003
#
# I      21_WTRP   22_ATRP     23_SER
# TIME
# 2019  0.039125  0.484792  52.015947
# 2020  0.039216  0.485920  51.537647
# 2021  0.041282  0.507919  53.638819
# 2022  0.043124  0.525119  54.465453
# 2023  0.044757  0.540714  55.296237
# 2024  0.046306  0.555663  56.094648
# 2025  0.047802  0.568986  56.885416
# 2026  0.049652  0.587327  58.013554
# 2027  0.051517  0.605403  59.140023
# 2028  0.053358  0.623183  60.255153
# 2029  0.055194  0.640615  61.370409
# 2030  0.057010  0.657781  62.472935
# 2031  0.058814  0.673928  63.313934
# 2032  0.060541  0.689614  64.137787
# 2033  0.062270  0.704769  64.969477
# 2034  0.063971  0.719920  65.785324
# 2035  0.065687  0.734709  66.611133
# 2036  0.067306  0.748636  67.207050
# 2037  0.068894  0.762111  67.809347
# 2038  0.070445  0.775275  68.398933
# 2039  0.071996  0.788194  68.992284
# 2040  0.073519  0.800860  69.574281
# 2041  0.075023  0.812882  70.012989
# 2042  0.076486  0.824600  70.442865
# 2043  0.077945  0.836118  70.875203
# 2044  0.079379  0.847378  71.298727
# 2045  0.080812  0.858476  71.723581
# 2046  0.082210  0.869058  72.023941
# 2047  0.083591  0.879423  72.325183
# 2048  0.084948  0.889533  72.620505
# 2049  0.086295  0.899439  72.914594
# 2050  0.087626  0.909133  73.203967
#
# [32 rows x 23 columns]
